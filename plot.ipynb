# %%
import csv
import numpy as np
import matplotlib.pyplot as plt

with open("raduis_data.csv") as f:
    reader = csv.reader(f)
#    next(reader) # skip header
    data = [r for r in reader]

print(data[:10])
# Out:
# [['235.73875133214867'], ['236.65782613652325'], ['236.70131197560315'], ['236.7418792069689'], ['236.7795439391599'], ['237.1182087637863'], ['236.87362118351922'], ['236.8138371867611'], ['236.7844266895017'], ['236.75840944886352']]

# %%
frame_rate = 37
x_data = []
y_data = []
for i in range(len(data)):
    x_data.append(i/frame_rate)
    y_data.append(float(data[i][0]))
    
plt.plot(x_data,y_data,marker='o',color='b')
#plt.xlim(0,60)
plt.show()
